# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime 

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 612

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
weather_url= url + weather_api_key
weather_url


#Found it here: https://openweathermap.org/faq#onecall 
# api.openweathermap.org/data/2.5/weather?id=524901&appid=YOUR_API_KEY
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?573b5ff1c795d38d97071fc17384bf73'

# %%
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    units= "metric"
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        #https://openweathermap.org/current
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahibadhoo
# Processing Record 2 of Set 1 | sarkand
# Processing Record 3 of Set 1 | hadibu
# Processing Record 4 of Set 1 | walvis bay
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | pennagaram
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | ranot
# Processing Record 9 of Set 1 | yorkton
# Processing Record 10 of Set 1 | isafjordur
# Processing Record 11 of Set 1 | tazovsky
# Processing Record 12 of Set 1 | xingcheng
# Processing Record 13 of Set 1 | barcelona
# Processing Record 14 of Set 1 | keflavik
# Processing Record 15 of Set 1 | margaret river
# Processing Record 16 of Set 1 | ocean pointe
# City not found. Skipping...
# Processing Record 17 of Set 1 | cartagena
# Processing Record 18 of Set 1 | port-aux-francais
# Processing Record 19 of Set 1 | porto novo
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | kourou
# Processing Record 22 of Set 1 | tonekabon
# Processing Record 23 of Set 1 | west island
# Processing Record 24 of Set 1 | el calafate
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | emerald
# Processing Record 27 of Set 1 | yaren
# Processing Record 28 of Set 1 | nemuro
# Processing Record 29 of Set 1 | bardai
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | grytviken
# Processing Record 32 of Set 1 | tolanaro
# Processing Record 33 of Set 1 | tamanrasset
# Processing Record 34 of Set 1 | yarmouth
# Processing Record 35 of Set 1 | bamboo flat
# Processing Record 36 of Set 1 | utrik
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | edinburgh of the seven seas
# Processing Record 39 of Set 1 | okhotsk
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | asuncion nochixtlan
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | waitangi
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | flying fish cove
# Processing Record 46 of Set 1 | zhaotong
# Processing Record 47 of Set 1 | weno
# Processing Record 48 of Set 1 | stanley
# Processing Record 49 of Set 1 | daira din panah
# Processing Record 50 of Set 1 | nar'yan-mar
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | santyoku
# Processing Record 3 of Set 2 | puerto ayora
# Processing Record 4 of Set 2 | muynoq
# Processing Record 5 of Set 2 | mocimboa
# Processing Record 6 of Set 2 | st. john's
# Processing Record 7 of Set 2 | ushuaia
# Processing Record 8 of Set 2 | sovetskiy
# Processing Record 9 of Set 2 | hawaiian paradise park
# Processing Record 10 of Set 2 | puerto natales
# Processing Record 11 of Set 2 | geraldton
# Processing Record 12 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | adamstown
# Processing Record 16 of Set 2 | la'ie
# Processing Record 17 of Set 2 | susuman
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | new norfolk
# Processing Record 20 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 21 of Set 2 | invercargill
# Processing Record 22 of Set 2 | kertih
# Processing Record 23 of Set 2 | labrador city
# Processing Record 24 of Set 2 | isetskoye
# Processing Record 25 of Set 2 | altai
# Processing Record 26 of Set 2 | alice springs
# Processing Record 27 of Set 2 | concepcion
# Processing Record 28 of Set 2 | governor's harbour
# City not found. Skipping...
# Processing Record 29 of Set 2 | mazagao
# Processing Record 30 of Set 2 | longyearbyen
# Processing Record 31 of Set 2 | koratla
# Processing Record 32 of Set 2 | petrovsk-zabaykal'skiy
# Processing Record 33 of Set 2 | ancud
# Processing Record 34 of Set 2 | polyarnyy
# Processing Record 35 of Set 2 | papatowai
# Processing Record 36 of Set 2 | nova sintra
# Processing Record 37 of Set 2 | antonio enes
# Processing Record 38 of Set 2 | nyurba
# Processing Record 39 of Set 2 | udachny
# Processing Record 40 of Set 2 | georgetown
# Processing Record 41 of Set 2 | arapgir
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | kiunga
# Processing Record 44 of Set 2 | peniche
# Processing Record 45 of Set 2 | al mindak
# Processing Record 46 of Set 2 | iskateley
# Processing Record 47 of Set 2 | tocopilla
# Processing Record 48 of Set 2 | boyolangu
# Processing Record 49 of Set 2 | port mathurin
# Processing Record 0 of Set 3 | tralee
# Processing Record 1 of Set 3 | naze
# Processing Record 2 of Set 3 | ulsan
# Processing Record 3 of Set 3 | malango
# Processing Record 4 of Set 3 | saint-pierre
# Processing Record 5 of Set 3 | itapirapua
# Processing Record 6 of Set 3 | launceston
# Processing Record 7 of Set 3 | guiuan
# Processing Record 8 of Set 3 | sosnovo-ozerskoye
# Processing Record 9 of Set 3 | pisco
# Processing Record 10 of Set 3 | tura
# Processing Record 11 of Set 3 | greenville
# Processing Record 12 of Set 3 | fort st. john
# Processing Record 13 of Set 3 | mataram
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | inari
# Processing Record 16 of Set 3 | lydenburg
# Processing Record 17 of Set 3 | nadym
# Processing Record 18 of Set 3 | houghton
# Processing Record 19 of Set 3 | daru
# Processing Record 20 of Set 3 | sao vicente
# Processing Record 21 of Set 3 | las tablas
# Processing Record 22 of Set 3 | praia da vitoria
# Processing Record 23 of Set 3 | ambon
# Processing Record 24 of Set 3 | santa rosa
# Processing Record 25 of Set 3 | kingscliff
# Processing Record 26 of Set 3 | olonkinbyen
# Processing Record 27 of Set 3 | eyl
# Processing Record 28 of Set 3 | taoudenni
# Processing Record 29 of Set 3 | hamilton
# Processing Record 30 of Set 3 | kuanda
# Processing Record 31 of Set 3 | nosy varika
# Processing Record 32 of Set 3 | port lincoln
# Processing Record 33 of Set 3 | levuka
# Processing Record 34 of Set 3 | yuzhno-kurilsk
# Processing Record 35 of Set 3 | knyaze-volkonskoye
# Processing Record 36 of Set 3 | nacozari viejo
# Processing Record 37 of Set 3 | bulayevo
# Processing Record 38 of Set 3 | touros
# Processing Record 39 of Set 3 | saudarkrokur
# Processing Record 40 of Set 3 | malmberget
# Processing Record 41 of Set 3 | hermoso campo
# Processing Record 42 of Set 3 | alamogordo
# Processing Record 43 of Set 3 | whitehorse
# Processing Record 44 of Set 3 | boksitogorsk
# Processing Record 45 of Set 3 | nuku'alofa
# Processing Record 46 of Set 3 | minas de marcona
# Processing Record 47 of Set 3 | urengoy
# Processing Record 48 of Set 3 | vorkuta
# Processing Record 49 of Set 3 | iqaluit
# Processing Record 0 of Set 4 | sasebo
# Processing Record 1 of Set 4 | tsiombe
# Processing Record 2 of Set 4 | saldanha
# Processing Record 3 of Set 4 | hirara
# Processing Record 4 of Set 4 | codrington
# Processing Record 5 of Set 4 | quang ngai
# Processing Record 6 of Set 4 | kerikeri
# Processing Record 7 of Set 4 | hailin
# Processing Record 8 of Set 4 | coquimbo
# Processing Record 9 of Set 4 | les cayes
# Processing Record 10 of Set 4 | kuytun
# Processing Record 11 of Set 4 | sao felix do xingu
# Processing Record 12 of Set 4 | bahia de caraquez
# Processing Record 13 of Set 4 | lhasa
# Processing Record 14 of Set 4 | castillos
# Processing Record 15 of Set 4 | chibougamau
# Processing Record 16 of Set 4 | ballina
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | sao joao da barra
# Processing Record 19 of Set 4 | vilyuchinsk
# Processing Record 20 of Set 4 | mukah
# City not found. Skipping...
# Processing Record 21 of Set 4 | outapi
# City not found. Skipping...
# Processing Record 22 of Set 4 | hasaki
# Processing Record 23 of Set 4 | deschutes river woods
# Processing Record 24 of Set 4 | jakobstad
# Processing Record 25 of Set 4 | ban ao nang
# Processing Record 26 of Set 4 | paradip garh
# Processing Record 27 of Set 4 | bilibino
# Processing Record 28 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 29 of Set 4 | zaozersk
# Processing Record 30 of Set 4 | luganville
# Processing Record 31 of Set 4 | mount isa
# Processing Record 32 of Set 4 | alesund
# Processing Record 33 of Set 4 | east london
# Processing Record 34 of Set 4 | manta
# Processing Record 35 of Set 4 | baruun-urt
# Processing Record 36 of Set 4 | shingu
# Processing Record 37 of Set 4 | poltavka
# Processing Record 38 of Set 4 | dunedin
# Processing Record 39 of Set 4 | badger
# Processing Record 40 of Set 4 | hillsboro
# Processing Record 41 of Set 4 | gorele
# Processing Record 42 of Set 4 | tangalle
# Processing Record 43 of Set 4 | enewetak
# Processing Record 44 of Set 4 | burang
# Processing Record 45 of Set 4 | ixtapa
# Processing Record 46 of Set 4 | melo
# Processing Record 47 of Set 4 | luau
# Processing Record 48 of Set 4 | cold lake
# Processing Record 49 of Set 4 | northam
# Processing Record 0 of Set 5 | lazaro cardenas
# Processing Record 1 of Set 5 | edson
# Processing Record 2 of Set 5 | withernsea
# Processing Record 3 of Set 5 | ilukste
# Processing Record 4 of Set 5 | vanino
# Processing Record 5 of Set 5 | college
# Processing Record 6 of Set 5 | kingston
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | seven pagodas
# Processing Record 9 of Set 5 | queenstown
# Processing Record 10 of Set 5 | carnarvon
# Processing Record 11 of Set 5 | makokou
# Processing Record 12 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 13 of Set 5 | shimoda
# Processing Record 14 of Set 5 | taunsa
# Processing Record 15 of Set 5 | wailua homesteads
# Processing Record 16 of Set 5 | urangan
# Processing Record 17 of Set 5 | at taj
# Processing Record 18 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 5 | constantia
# Processing Record 20 of Set 5 | mitu
# Processing Record 21 of Set 5 | luderitz
# Processing Record 22 of Set 5 | novodvinsk
# Processing Record 23 of Set 5 | al khawr
# Processing Record 24 of Set 5 | malvan
# Processing Record 25 of Set 5 | franceville
# Processing Record 26 of Set 5 | yershov
# Processing Record 27 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 28 of Set 5 | rongelap
# Processing Record 29 of Set 5 | papireddippatti
# Processing Record 30 of Set 5 | ta`u
# Processing Record 31 of Set 5 | beyneu
# Processing Record 32 of Set 5 | fortuna
# Processing Record 33 of Set 5 | vallo della lucania
# Processing Record 34 of Set 5 | tionk essil
# Processing Record 35 of Set 5 | khilok
# Processing Record 36 of Set 5 | vorgashor
# Processing Record 37 of Set 5 | illizi
# Processing Record 38 of Set 5 | zeya
# Processing Record 39 of Set 5 | mount gambier
# Processing Record 40 of Set 5 | viqueque
# Processing Record 41 of Set 5 | afaahiti
# Processing Record 42 of Set 5 | lompoc
# Processing Record 43 of Set 5 | mejit
# Processing Record 44 of Set 5 | kenai
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | ipatovo
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | nogliki
# Processing Record 49 of Set 5 | karagay
# Processing Record 0 of Set 6 | coari
# Processing Record 1 of Set 6 | caala
# Processing Record 2 of Set 6 | saipan
# Processing Record 3 of Set 6 | sarh
# Processing Record 4 of Set 6 | hotan
# Processing Record 5 of Set 6 | mata-utu
# Processing Record 6 of Set 6 | fomboni
# Processing Record 7 of Set 6 | gore
# Processing Record 8 of Set 6 | forster
# Processing Record 9 of Set 6 | atafu village
# Processing Record 10 of Set 6 | don sak
# Processing Record 11 of Set 6 | kokstad
# Processing Record 12 of Set 6 | strezhevoy
# Processing Record 13 of Set 6 | jamestown
# Processing Record 14 of Set 6 | dabakala
# Processing Record 15 of Set 6 | neietsu
# Processing Record 16 of Set 6 | north bend
# Processing Record 17 of Set 6 | phek
# Processing Record 18 of Set 6 | aykol
# City not found. Skipping...
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | suva
# Processing Record 21 of Set 6 | manokwari
# Processing Record 22 of Set 6 | oistins
# Processing Record 23 of Set 6 | brookings
# Processing Record 24 of Set 6 | ntoum
# Processing Record 25 of Set 6 | san andres
# Processing Record 26 of Set 6 | trinidad
# Processing Record 27 of Set 6 | lebu
# Processing Record 28 of Set 6 | recani
# Processing Record 29 of Set 6 | robore
# Processing Record 30 of Set 6 | berdigestyakh
# Processing Record 31 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 32 of Set 6 | saacow
# Processing Record 33 of Set 6 | fort bragg
# Processing Record 34 of Set 6 | korhogo
# Processing Record 35 of Set 6 | brokopondo
# Processing Record 36 of Set 6 | mabaruma
# Processing Record 37 of Set 6 | helena valley west central
# Processing Record 38 of Set 6 | ardestan
# Processing Record 39 of Set 6 | tiksi
# Processing Record 40 of Set 6 | marat
# Processing Record 41 of Set 6 | balabac
# Processing Record 42 of Set 6 | san antonio de pale
# Processing Record 43 of Set 6 | kaihua
# Processing Record 44 of Set 6 | lago da pedra
# Processing Record 45 of Set 6 | mucumpiz
# Processing Record 46 of Set 6 | kapuskasing
# Processing Record 47 of Set 6 | whakatane
# Processing Record 48 of Set 6 | burao
# Processing Record 49 of Set 6 | uturoa
# Processing Record 0 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 1 of Set 7 | markovo
# Processing Record 2 of Set 7 | bontoc
# Processing Record 3 of Set 7 | iacu
# Processing Record 4 of Set 7 | sale
# Processing Record 5 of Set 7 | sabang
# Processing Record 6 of Set 7 | nishinoomote
# Processing Record 7 of Set 7 | lerwick
# Processing Record 8 of Set 7 | bazarnyy karabulak
# Processing Record 9 of Set 7 | boa vista
# Processing Record 10 of Set 7 | aquin
# Processing Record 11 of Set 7 | el granada
# Processing Record 12 of Set 7 | arno
# Processing Record 13 of Set 7 | smara
# Processing Record 14 of Set 7 | as samawah
# Processing Record 15 of Set 7 | cabo san lucas
# Processing Record 16 of Set 7 | oyugis
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | rodnikovskaya
# Processing Record 20 of Set 7 | gaigeturi
# Processing Record 21 of Set 7 | mozarlandia
# Processing Record 22 of Set 7 | faya-largeau
# Processing Record 23 of Set 7 | pula
# Processing Record 24 of Set 7 | yaguachi nuevo
# Processing Record 25 of Set 7 | zouerate
# Processing Record 26 of Set 7 | alofi
# Processing Record 27 of Set 7 | thunder bay
# Processing Record 28 of Set 7 | midelt
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | mecca
# Processing Record 31 of Set 7 | happy valley-goose bay
# Processing Record 32 of Set 7 | kodinar
# Processing Record 33 of Set 7 | punta alta
# Processing Record 34 of Set 7 | nova vicosa
# Processing Record 35 of Set 7 | phuntsholing
# Processing Record 36 of Set 7 | punta del este
# Processing Record 37 of Set 7 | sal rei
# Processing Record 38 of Set 7 | gadzhiyevo
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | horta
# Processing Record 41 of Set 7 | tha khanon
# Processing Record 42 of Set 7 | boradigah
# Processing Record 43 of Set 7 | hosur
# Processing Record 44 of Set 7 | am timan
# Processing Record 45 of Set 7 | aasiaat
# Processing Record 46 of Set 7 | port douglas
# Processing Record 47 of Set 7 | brazzaville
# Processing Record 48 of Set 7 | pushkinskiye gory
# Processing Record 49 of Set 7 | vila franca do campo
# Processing Record 0 of Set 8 | uttar char fasson
# Processing Record 1 of Set 8 | pasil
# Processing Record 2 of Set 8 | roccella ionica
# Processing Record 3 of Set 8 | hassi messaoud
# Processing Record 4 of Set 8 | zunyi
# Processing Record 5 of Set 8 | akureyri
# Processing Record 6 of Set 8 | vingt cinq
# City not found. Skipping...
# Processing Record 7 of Set 8 | chinde
# Processing Record 8 of Set 8 | balykshi
# Processing Record 9 of Set 8 | ust-tsilma
# Processing Record 10 of Set 8 | aswan
# Processing Record 11 of Set 8 | shalqar
# Processing Record 12 of Set 8 | kupang
# Processing Record 13 of Set 8 | arroio grande
# Processing Record 14 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 8 | hithadhoo
# Processing Record 16 of Set 8 | yel'nya
# Processing Record 17 of Set 8 | mount pleasant
# Processing Record 18 of Set 8 | gan
# Processing Record 19 of Set 8 | natal
# Processing Record 20 of Set 8 | fale old settlement
# Processing Record 21 of Set 8 | yeraliyev
# Processing Record 22 of Set 8 | howard springs
# Processing Record 23 of Set 8 | itamaraju
# Processing Record 24 of Set 8 | aroma
# Processing Record 25 of Set 8 | moissala
# Processing Record 26 of Set 8 | val-d'or
# Processing Record 27 of Set 8 | qamdo
# Processing Record 28 of Set 8 | mossel bay
# Processing Record 29 of Set 8 | bayanaul
# Processing Record 30 of Set 8 | rikaze
# Processing Record 31 of Set 8 | zernograd
# Processing Record 32 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 8 | toccoa
# Processing Record 34 of Set 8 | kudat
# Processing Record 35 of Set 8 | hemsby
# Processing Record 36 of Set 8 | cloquet
# Processing Record 37 of Set 8 | meadow lakes
# Processing Record 38 of Set 8 | kibakwe
# Processing Record 39 of Set 8 | sandnessjoen
# Processing Record 40 of Set 8 | ventspils
# Processing Record 41 of Set 8 | terespol
# Processing Record 42 of Set 8 | caxias
# Processing Record 43 of Set 8 | qaisumah
# Processing Record 44 of Set 8 | erwin
# Processing Record 45 of Set 8 | laojunmiao
# Processing Record 46 of Set 8 | maintirano
# Processing Record 47 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 48 of Set 8 | esik
# Processing Record 49 of Set 8 | daxi
# Processing Record 0 of Set 9 | todos santos
# Processing Record 1 of Set 9 | kharsia
# Processing Record 2 of Set 9 | nuuk
# Processing Record 3 of Set 9 | skrunda
# Processing Record 4 of Set 9 | aral
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | vrnjacka banja
# Processing Record 7 of Set 9 | kirakira
# Processing Record 8 of Set 9 | aykhal
# Processing Record 9 of Set 9 | ayancik
# Processing Record 10 of Set 9 | ust-nera
# Processing Record 11 of Set 9 | vilyuysk
# Processing Record 12 of Set 9 | bel ombre
# Processing Record 13 of Set 9 | khorixas
# Processing Record 14 of Set 9 | kamiiso
# Processing Record 15 of Set 9 | tenno
# Processing Record 16 of Set 9 | esperantinopolis
# Processing Record 17 of Set 9 | port antonio
# Processing Record 18 of Set 9 | hargeysa
# Processing Record 19 of Set 9 | puerto san jose
# Processing Record 20 of Set 9 | timbuktu
# Processing Record 21 of Set 9 | arraial do cabo
# Processing Record 22 of Set 9 | tabou
# Processing Record 23 of Set 9 | newman
# Processing Record 24 of Set 9 | amahai
# Processing Record 25 of Set 9 | ugoofaaru
# Processing Record 26 of Set 9 | coron
# Processing Record 27 of Set 9 | egilsstadir
# Processing Record 28 of Set 9 | dudinka
# Processing Record 29 of Set 9 | lagawe
# Processing Record 30 of Set 9 | al hazm
# Processing Record 31 of Set 9 | dalby
# Processing Record 32 of Set 9 | cambria
# Processing Record 33 of Set 9 | devgarh
# Processing Record 34 of Set 9 | presidente epitacio
# Processing Record 35 of Set 9 | gilgit
# Processing Record 36 of Set 9 | dong ha
# Processing Record 37 of Set 9 | labytnangi
# Processing Record 38 of Set 9 | rio grande
# Processing Record 39 of Set 9 | nizhneudinsk
# Processing Record 40 of Set 9 | gizo
# Processing Record 41 of Set 9 | tobelo
# Processing Record 42 of Set 9 | parkersburg
# Processing Record 43 of Set 9 | nova xavantina
# Processing Record 44 of Set 9 | lihue
# Processing Record 45 of Set 9 | vytegra
# Processing Record 46 of Set 9 | san miguel de salinas
# Processing Record 47 of Set 9 | talara
# Processing Record 48 of Set 9 | shenjiamen
# Processing Record 49 of Set 9 | oroqen zizhiqi
# Processing Record 0 of Set 10 | baiti
# Processing Record 1 of Set 10 | xunchang
# Processing Record 2 of Set 10 | issoire
# Processing Record 3 of Set 10 | ulsteinvik
# Processing Record 4 of Set 10 | sugar grove
# Processing Record 5 of Set 10 | diboll
# Processing Record 6 of Set 10 | ciudad lazaro cardenas
# Processing Record 7 of Set 10 | kruisfontein
# Processing Record 8 of Set 10 | broome
# Processing Record 9 of Set 10 | mockrehna
# Processing Record 10 of Set 10 | tobruk
# Processing Record 11 of Set 10 | laguna
# Processing Record 12 of Set 10 | pibor
# City not found. Skipping...
# Processing Record 13 of Set 10 | ar rass
# Processing Record 14 of Set 10 | khlung
# Processing Record 15 of Set 10 | conception bay south
# Processing Record 16 of Set 10 | baise city
# Processing Record 17 of Set 10 | richards bay
# Processing Record 18 of Set 10 | kotel'nich
# Processing Record 19 of Set 10 | chazuta
# Processing Record 20 of Set 10 | piacabucu
# Processing Record 21 of Set 10 | esquina
# Processing Record 22 of Set 10 | wynyard
# Processing Record 23 of Set 10 | pakala
# Processing Record 24 of Set 10 | faranah
# Processing Record 25 of Set 10 | vadso
# Processing Record 26 of Set 10 | mokhsogollokh
# Processing Record 27 of Set 10 | crane
# Processing Record 28 of Set 10 | mandalgovi
# Processing Record 29 of Set 10 | izobil'nyy
# Processing Record 30 of Set 10 | weining
# Processing Record 31 of Set 10 | linda
# Processing Record 32 of Set 10 | kataragama
# City not found. Skipping...
# Processing Record 33 of Set 10 | cockburn town
# Processing Record 34 of Set 10 | dalai
# Processing Record 35 of Set 10 | don luan
# Processing Record 36 of Set 10 | manchar
# Processing Record 37 of Set 10 | phan rang-thap cham
# Processing Record 38 of Set 10 | yung shue wan
# Processing Record 39 of Set 10 | ternate
# Processing Record 40 of Set 10 | tanumah
# Processing Record 41 of Set 10 | yei
# Processing Record 42 of Set 10 | kalabo
# Processing Record 43 of Set 10 | klyuchi
# Processing Record 44 of Set 10 | devils lake
# Processing Record 45 of Set 10 | pskov
# Processing Record 46 of Set 10 | kitimat
# Processing Record 47 of Set 10 | katsuura
# Processing Record 48 of Set 10 | nazarabad
# Processing Record 49 of Set 10 | manggar
# Processing Record 0 of Set 11 | strathalbyn
# Processing Record 1 of Set 11 | vila velha
# Processing Record 2 of Set 11 | soio
# Processing Record 3 of Set 11 | tha bo
# Processing Record 4 of Set 11 | fort irwin
# Processing Record 5 of Set 11 | antofagasta
# Processing Record 6 of Set 11 | port blair
# Processing Record 7 of Set 11 | jaicos
# Processing Record 8 of Set 11 | al jawf
# Processing Record 9 of Set 11 | rio gallegos
# Processing Record 10 of Set 11 | chonchi
# Processing Record 11 of Set 11 | lake monticello
# Processing Record 12 of Set 11 | broken hill
# Processing Record 13 of Set 11 | vieste
# Processing Record 14 of Set 11 | shumen
# Processing Record 15 of Set 11 | hanting
# Processing Record 16 of Set 11 | kristiansund
# Processing Record 17 of Set 11 | lycksele
# Processing Record 18 of Set 11 | villa gesell
# Processing Record 19 of Set 11 | dryden
# Processing Record 20 of Set 11 | xinyuan
# Processing Record 21 of Set 11 | adrar
# Processing Record 22 of Set 11 | ibimirim
# Processing Record 23 of Set 11 | nhamunda
# Processing Record 24 of Set 11 | al ghayzah
# Processing Record 25 of Set 11 | qusmuryn
# Processing Record 26 of Set 11 | almeirim
# Processing Record 27 of Set 11 | namibe
# Processing Record 28 of Set 11 | albertina
# Processing Record 29 of Set 11 | benguela
# Processing Record 30 of Set 11 | taunggyi
# Processing Record 31 of Set 11 | mezhdurechenskiy
# Processing Record 32 of Set 11 | swiebodzin
# Processing Record 33 of Set 11 | tianpeng
# Processing Record 34 of Set 11 | nichinan
# Processing Record 35 of Set 11 | ahau
# City not found. Skipping...
# Processing Record 36 of Set 11 | angaur state
# Processing Record 37 of Set 11 | tayu
# Processing Record 38 of Set 11 | freetown
# Processing Record 39 of Set 11 | mahanoro
# Processing Record 40 of Set 11 | eenhana
# Processing Record 41 of Set 11 | keren
# Processing Record 42 of Set 11 | amga
# Processing Record 43 of Set 11 | matthew town
# Processing Record 44 of Set 11 | shanhecun
# Processing Record 45 of Set 11 | tual
# Processing Record 46 of Set 11 | gebeit
# Processing Record 47 of Set 11 | czerwonak
# Processing Record 48 of Set 11 | antsiranana
# Processing Record 49 of Set 11 | kaset sombun
# Processing Record 0 of Set 12 | gao
# Processing Record 1 of Set 12 | afua
# Processing Record 2 of Set 12 | tucuma
# Processing Record 3 of Set 12 | la passe
# Processing Record 4 of Set 12 | formiga
# Processing Record 5 of Set 12 | san patricio
# Processing Record 6 of Set 12 | stranraer
# Processing Record 7 of Set 12 | mitchell
# Processing Record 8 of Set 12 | bodo
# Processing Record 9 of Set 12 | esquel
# Processing Record 10 of Set 12 | monrovia
# Processing Record 11 of Set 12 | igarka
# Processing Record 12 of Set 12 | merizo village
# Processing Record 13 of Set 12 | sisimiut
# Processing Record 14 of Set 12 | nkurenkuru
# City not found. Skipping...
# Processing Record 15 of Set 12 | kigoma
# Processing Record 16 of Set 12 | kimberley
# Processing Record 17 of Set 12 | mangochi
# Processing Record 18 of Set 12 | changli
# Processing Record 19 of Set 12 | mazabuka
# Processing Record 20 of Set 12 | usinsk
# Processing Record 21 of Set 12 | nova olinda do norte
# Processing Record 22 of Set 12 | kone
# Processing Record 23 of Set 12 | severo-yeniseyskiy
# Processing Record 24 of Set 12 | paranaiba
# Processing Record 25 of Set 12 | khash
# Processing Record 26 of Set 12 | ruidoso
# Processing Record 27 of Set 12 | xiangtan
# Processing Record 28 of Set 12 | la foa
# Processing Record 29 of Set 12 | heyuan
# Processing Record 30 of Set 12 | calp
# Processing Record 31 of Set 12 | forquilhinha
# Processing Record 32 of Set 12 | hakkari
# Processing Record 33 of Set 12 | acarau
# Processing Record 34 of Set 12 | berezovyy
# Processing Record 35 of Set 12 | balkanabat
# Processing Record 36 of Set 12 | prado
# Processing Record 37 of Set 12 | attapeu
# Processing Record 38 of Set 12 | richland
# Processing Record 39 of Set 12 | trairi
# Processing Record 40 of Set 12 | bikenibeu village
# Processing Record 41 of Set 12 | adh dhibiyah
# City not found. Skipping...
# Processing Record 42 of Set 12 | murrells inlet
# Processing Record 43 of Set 12 | acolla
# Processing Record 44 of Set 12 | fannuj
# City not found. Skipping...
# Processing Record 45 of Set 12 | buka
# Processing Record 46 of Set 12 | awjilah
# Processing Record 47 of Set 12 | si satchanalai
# Processing Record 48 of Set 12 | kununurra
# Processing Record 49 of Set 12 | an nuhud
# Processing Record 0 of Set 13 | murmashi
# Processing Record 1 of Set 13 | kurchatov
# Processing Record 2 of Set 13 | ar ruways
# Processing Record 3 of Set 13 | calamba
# Processing Record 4 of Set 13 | kuta
# Processing Record 5 of Set 13 | marsa alam
# Processing Record 6 of Set 13 | bushland beach
# City not found. Skipping...
# Processing Record 7 of Set 13 | tromso
# Processing Record 8 of Set 13 | costa calma
# City not found. Skipping...
# Processing Record 9 of Set 13 | amlapura
# Processing Record 10 of Set 13 | ta'izz
# Processing Record 11 of Set 13 | constitucion
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -72.4167, 'lat': -35.3333},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 15.71,
#   'feels_like': 15.37,
#   'temp_min': 15.71,
#   'temp_max': 15.71,
#   'pressure': 1015,
#   'humidity': 78,
#   'sea_level': 1015,
#   'grnd_level': 1012},
#  'visibility': 10000,
#  'wind': {'speed': 2.1, 'deg': 169, 'gust': 3.65},
#  'clouds': {'all': 94},
#  'dt': 1711449544,
#  'sys': {'country': 'CL', 'sunrise': 1711450678, 'sunset': 1711493531},
#  'timezone': -10800,
#  'id': 3893726,
#  'name': 'Constitución',
#  'cod': 200}

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df=pd.DataFrame(city_data, columns =['City', 'Lat', 'Lng', 'Max Temp','Humidity','Cloudiness','Wind Speed','Country','Date'])
# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  mahibadhoo   3.7833  72.9667     28.61        77         100        5.63
# 1     sarkand  45.4100  79.9186     16.93        46          18        2.55
# 2      hadibu  12.6500  54.0333     29.95        66           1        4.06
# 3  walvis bay -22.9575  14.5053     18.94        54          93        4.69
# 4      bethel  41.3712 -73.4140      3.44        63         100        3.09
#
#   Country        Date
# 0      MV  1711447174
# 1      KZ  1711447175
# 2      YE  1711447175
# 3      NA  1711446902
# 4      US  1711446927

# %%
#Update: I realized when I was almost done with VacationPy that these units are actually in Kelvin rather than Celsius not sure why it did that but I'll just convert it here. 

# Convert temperature columns from Kelvin to Celsius
city_data_df['Max Temp'] = city_data_df['Max Temp'] - 273.15

city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mahibadhoo   3.7833  72.9667   -790.06        76         100
# 1           sarkand  45.4100  79.9186   -806.31        50           2
# 2            hadibu  12.6500  54.0333   -791.14        71           5
# 3        walvis bay -22.9575  14.5053   -802.73        81          28
# 4            bethel  41.3712 -73.4140   -816.25        54           0
#
#          Wind Speed Country                Date
# City_ID
# 0              5.15      MV 2024-03-26 05:18:17
# 1              3.12      KZ 2024-03-26 05:18:17
# 2              2.17      YE 2024-03-26 05:09:41
# 3              5.05     NaN 2024-03-26 05:11:41
# 4              5.14      US 2024-03-26 05:09:25

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mahibadhoo   3.7833  72.9667     28.61        77         100
# 1           sarkand  45.4100  79.9186     16.93        46          18
# 2            hadibu  12.6500  54.0333     29.95        66           1
# 3        walvis bay -22.9575  14.5053     18.94        54          93
# 4            bethel  41.3712 -73.4140      3.44        63         100
#
#          Wind Speed Country        Date
# City_ID
# 0              5.63      MV  1711447174
# 1              2.55      KZ  1711447175
# 2              4.06      YE  1711447175
# 3              4.69     NaN  1711446902
# 4              3.09      US  1711446927

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# convert dt to yyyy-mm-dd and #test
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'],unit='s')
city_data_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mahibadhoo   3.7833  72.9667     28.61        77         100
# 1           sarkand  45.4100  79.9186     16.93        46          18
# 2            hadibu  12.6500  54.0333     29.95        66           1
# 3        walvis bay -22.9575  14.5053     18.94        54          93
# 4            bethel  41.3712 -73.4140      3.44        63         100
#
#          Wind Speed Country                Date
# City_ID
# 0              5.63      MV 2024-03-26 09:59:34
# 1              2.55      KZ 2024-03-26 09:59:35
# 2              4.06      YE 2024-03-26 09:59:35
# 3              4.69     NaN 2024-03-26 09:55:02
# 4              3.09      US 2024-03-26 09:55:27

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker="o")
# Incorporate the other graph properties
plt.title(f"City Max Latitude vs. Temperature(2024-03-26)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity (2024-03-26)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness (2024-03-26)")
plt.ylabel("Cloudiness(%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o")
# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed (2024-03-26)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Linear Regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))


plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title(title)
plt.xlabel(x_values)
plt.ylabel(y_values)
plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data                 
northern_hemi_df.head()
# Out:
#                City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        mahibadhoo   3.7833  72.9667     28.61        77         100
# 1           sarkand  45.4100  79.9186     16.93        46          18
# 2            hadibu  12.6500  54.0333     29.95        66           1
# 4            bethel  41.3712 -73.4140      3.44        63         100
# 5        pennagaram  12.1333  77.9000     34.66        15           0
#
#          Wind Speed Country                Date
# City_ID
# 0              5.63      MV 2024-03-26 09:59:34
# 1              2.55      KZ 2024-03-26 09:59:35
# 2              4.06      YE 2024-03-26 09:59:35
# 4              3.09      US 2024-03-26 09:55:27
# 5              5.76      IN 2024-03-26 09:59:36

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data                 
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3               walvis bay -22.9575   14.5053     18.94        54          93
# 6            blackmans bay -43.0167  147.3167     16.07        72          74
# 14          margaret river -33.9500  115.0667     19.51        68           2
# 16       port-aux-francais -49.3500   70.2167      3.56        67          98
# 21             west island -12.1568   96.8225     29.99        74          75
#
#          Wind Speed Country                Date
# City_ID
# 3              4.69     NaN 2024-03-26 09:55:02
# 6              2.96      AU 2024-03-26 09:59:37
# 14             5.23      AU 2024-03-26 09:59:41
# 16            16.32      TF 2024-03-26 09:59:42
# 21             5.14      CC 2024-03-26 09:59:44

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
#Create Scatter Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values

regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.69x + 37.45

# %%
# Linear regression on Northern Hemisphere
# Create Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegNorth1.png")
# Out:
# The r-value is: 0.7918729833081153

# %%
# Linear regression on Southern Hemisphere

# Create Plot
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegSouth1.png")
# Out:
# The r-value is: 0.5673783425578824
# The linear equation is: y = 0.32x + 29.57

# %% [markdown]
# **Discussion about the linear relationship:** Based on the graph and r-value there is a moderate positive correlation between latitude and maximum temperature for southern hemisphere while a strong negative correlation for nothern hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Humidity vs. Latitude Linear Regression Plot on Northern Hemisphere

# Create Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegNorth2.png")
# Out:
# The r-value is: 0.11392957272977264
# The linear equation is: y = 0.43x + 49.04

# %%
# Humidity vs. Latitude Linear Regression Plot on Southern Hemisphere
# Create Plot
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegSouth2.png")
# Out:
# The r-value is: 0.011559566439004793
# The linear equation is: y = 0.13x + 80.97

# %% [markdown]
# **Discussion about the linear relationship:** In these graphs, the points are scattered showing no correlation between humidity and latitude.The r-value is 0.011 indicating that it's very weak/no correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Cloudiness vs. Latitude Linear Regression Plot on Northern Hemisphere
# Create Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegNorth3.png")
# Out:
# The r-value is: 0.05321198176520084
# The linear equation is: y = 0.46x + 44.49

# %%
# Cloudiness vs. Latitude Linear Regression Plot on Southern Hemisphere
# Create Plot
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegSouth3.png")
# Out:
# The r-value is: 0.0767180463380379
# The linear equation is: y = 0.71x + 82.45

# %% [markdown]
# **Discussion about the linear relationship:** Here it seems as though the points are scattered making it seem like there is no correlation between cloudiness and latitude in both hemispheres. Either way, the r-value is 0.055 and 0.79 which makes it moderate and strong.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Wind Speed vs. Latitude Linear Regression Plot on Northern Hemisphere
# Create Plot
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegNorth4.png")
# Out:
# The r-value is: 0.0033531021292784666
# The linear equation is: y = -0.01x + 4.68

# %%
# Wind Speed vs. Latitude Linear Regression Plot on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
# Get regression values
regress_values = x_values * slope + intercept
#Get Linear equation
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
# Print r value
print(f"The r-value is: {rvalue**2}")
print(f"The linear equation is: {line_eq}")


# Show plot
plt.show()

plt.savefig("output_data/LinRegSouth4.png")
# Out:
# The r-value is: 0.05210813605978988
# The linear equation is: y = -0.04x + 2.29

# %% [markdown]
# **Discussion about the linear relationship:** The points tend be scattered downwards and with a r-value of 0.003 and 0.05.There is a moderate negative correlation with wind speed, latitude in southern hemisphere. However, the northern hemisphere has a weak no correlation with 0.003.

# %% [markdown]
# References:
# https://openweathermap.org/current
# https://openweathermap.org/faq#onecall
# -In Class Activities
